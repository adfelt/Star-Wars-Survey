# %% [markdown]
# # Star Wars Survey
#
# While waiting for Star Wars: The Force Awakens to come out, the team at FiveThirtyEight became interested in answering some questions about Star Wars fans. In particular, they wondered: does the rest of America realize that **“The Empire Strikes Back”** is clearly the best of the bunch?
#
# In order to address these questions FiveThirtyEight sent out a survey and recieved 835 total responses.
#
# I will be analyzing those responses and hopefully drawing some useful insights about people's opinions of the Star Wars saga.

# %%
import pandas as pd
import numpy as np 
star_wars = pd.read_csv("__data__/star_wars.csv", encoding="ISO-8859-1")

# %%
star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'seen_1', 'seen_2', 'seen_3', 'seen_4', 'seen_5', 'seen_6', 'rank_1',
#        'rank_2', 'rank_3', 'rank_4', 'rank_5', 'rank_6',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
#        'Are you familiar with the Expanded Universe?',
#        'Do you consider yourself to be a fan of the Expanded Universe?ÂÃ¦',
#        'Do you consider yourself to be a fan of the Star Trek franchise?',
#        'Gender', 'Age', 'Household Income', 'Education',
# ...

# %%
# Removed all the rows where RespondentID contained a null value.
star_wars = star_wars[pd.notnull(star_wars['RespondentID'])]

# %%
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
# 5                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
# Created a map which converted, 'Yes, No' to boolean values.
yes_no = {"Yes": True,"No": False}

# Looped through these two columns and replaced all the Yes, No values with bools
for c in ['Have you seen any of the 6 films in the Star Wars franchise?',\
    'Do you consider yourself to be a fan of the Star Wars film franchise?']:
    star_wars[c] = star_wars[c].map(yes_no)

star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
# Created a map to change these movie values to simple boolean values
movie_mapping = {"Star Wars: Episode I  The Phantom Menace": True,
    np.nan: False,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True}

# Looped through the columns and applyed my map
for c in star_wars.columns[3:9]:
    star_wars[c] = star_wars[c].map(movie_mapping)

# %%
# Renamed the columns so they would make more intuitive sense.
star_wars = star_wars.rename(columns={'Which of the following Star Wars films have you seen? Please select all that apply.':'seen_1',
       'Unnamed: 4':'seen_2', 'Unnamed: 5':'seen_3', 'Unnamed: 6':'seen_4', 'Unnamed: 7':'seen_5', 'Unnamed: 8':'seen_6'})

# %%
star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                                NaN
# 3                                              False
# 4                                               True
# 5                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 1    True    True    True    True    True    True
# 2   False   False   False   False   False   False
# 3    True    True    True   False   False   False
# ...

# %%
# Changing each columns that rank people's favorite Star Wars movies to floats.
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# Renaming the rankings columns
star_wars = star_wars.rename(columns={'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.':'rank_1',
       'Unnamed: 10':'rank_2', 'Unnamed: 11':'rank_3', 'Unnamed: 12':'rank_4', 'Unnamed: 13':'rank_5',
       'Unnamed: 14':'rank_6'})

# %%
# Finding the mean of the ranking columns
rankings = star_wars.iloc[:,9:15].mean()
# Out:
# rank_1    3.732934
# rank_2    4.087321
# rank_3    4.341317
# rank_4    3.272727
# rank_5    2.513158
# rank_6    3.047847
# dtype: float64

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
# Plotting the rankings 
plt.bar(range(1,7), star_wars.iloc[:,9:15].mean())
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # Summary so Far
#
# I've done a few things with this dataset.
#
# First I cleaned several Yes, No survey questions by converting the "Yes, No" answers to boolean values so we could use them more easily later on in my analysis. Next I cleand the rankings columns, converting them to floats and renmaing the columns.
#
# Finally we found the average ranking for each movie and plotted the rankings in a bar chart.
#
#
# ### Observations
# Unsuprisingly people ranked the original trilogy the highest and the prequels the lowest.
#
# People's rankings of Revenge of the Sith does suprise me. Especially that the Phantom Menace is ranked higher. It will take some further investigation to determine what is going on here.

# %%
seen_cols = ['seen_1', 'seen_2', 'seen_3', 'seen_4', 'seen_5', 'seen_6']
counter = 0
for c in seen_cols:
    counter += 1
    print(f'{sum(star_wars[c])} have seen Star Wars Episode {counter}')

plt.bar(range(1,7), star_wars.iloc[:,3:9].sum())
# Out:
# 673 have seen Star Wars Episode 1
# 571 have seen Star Wars Episode 2
# 550 have seen Star Wars Episode 3
# 607 have seen Star Wars Episode 4
# 758 have seen Star Wars Episode 5
# 738 have seen Star Wars Episode 6
# <BarContainer object of 6 artists>

# %% [markdown]
# ## Viewership
#
# So, it appears that more people have seen episodes V and VI than any of the other films. In all reality it does appear that there might be a correlation between the amount of people who have seen a film and it's ranking.  While having higher viewership could affect the rating negatively it doesn't appear that has happened.
#
# The rankings line up almost perfectly with the number of people who watched it. With the exception of episode I.  While it did achieve a better ranking than both episodes II and III, it came just behind episode IV.
#
# While I'm not suprised by these findings I do think it's interesting that despite this being a small survey 100+ people reported seeing episode I and not episode III.  I would be curious to see if this reflects the general population.

# %%
# Gender and ranking/viewership
# Let's see how Males and Females responeded differently to these questions.

# I'll start by segmenting the audience
males = star_wars[star_wars["Gender"] == "Male"]
females = star_wars[star_wars["Gender"] == "Female"]

# %%
# Finding the mean of the ranking columns - Males
rankings = males.iloc[:,9:15].mean()

# Plotting the rankings - Males
plt.bar(range(1,7), males.iloc[:,9:15].mean())
print(rankings)
# Out:
# rank_1    4.037825
# rank_2    4.224586
# rank_3    4.274882
# rank_4    2.997636
# rank_5    2.458629
# rank_6    3.002364
# dtype: float64

# %%
# Finding the mean of the ranking columns - Females
rankings = females.iloc[:,9:15].mean()

# Plotting the rankings - Females
plt.bar(range(1,7), females.iloc[:,9:15].mean())
print(rankings)
# Out:
# rank_1    3.429293
# rank_2    3.954660
# rank_3    4.418136
# rank_4    3.544081
# rank_5    2.569270
# rank_6    3.078086
# dtype: float64

# %%
# Viewership - Males
counter = 0
for c in seen_cols:
    counter += 1
    print(f'{sum(males[c])} males have seen Star Wars Episode {counter}')

plt.bar(range(1,7), males.iloc[:,3:9].sum())
# Out:
# 361 males have seen Star Wars Episode 1
# 323 males have seen Star Wars Episode 2
# 317 males have seen Star Wars Episode 3
# 342 males have seen Star Wars Episode 4
# 392 males have seen Star Wars Episode 5
# 387 males have seen Star Wars Episode 6
# <BarContainer object of 6 artists>

# %%
# Viewership - Females
counter = 0
for c in seen_cols:
    counter += 1
    print(f'{sum(females[c])} females have seen Star Wars Episode {counter}')

plt.bar(range(1,7), females.iloc[:,3:9].sum())
# Out:
# 298 females have seen Star Wars Episode 1
# 237 females have seen Star Wars Episode 2
# 222 females have seen Star Wars Episode 3
# 255 females have seen Star Wars Episode 4
# 353 females have seen Star Wars Episode 5
# 338 females have seen Star Wars Episode 6
# <BarContainer object of 6 artists>
